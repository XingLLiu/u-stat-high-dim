# %%
import sys
sys.path.append("../")

# %%
# %load_ext autoreload
# %autoreload 2

from src.ksd.ksd import KSD
from src.ksd.kernel import IMQ, RBF

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm, trange

import high_dim_power as hd

import matplotlib as mpl
mpl.rcParams["mathtext.fontset"] = "cm"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tf.random.set_seed(1)

# DELTA = 0.01
DELTA = 0.1

# %%
# target, proposal = hd.generate_target_proposal(2, DELTA)
target, proposal = hd.generate_target_proposal_t(2, DELTA, df=5)

target_x = target.sample(1000)
proposal_x = proposal.sample(1000)

fig, ax = plt.subplots()
ax.scatter(target_x[:, 0], target_x[:, 1], label="target")
ax.scatter(proposal_x[:, 0], proposal_x[:, 1], label="proposal")
ax.legend()
plt.show()

# %%
# dims = [1, 4, 16, 64, 256]
dims = [4, 16, 64, 128, 192, 256, 512, 1024, 2048]
res_analytical = hd.compute_population_quantities(dims, bandwidth_order=1., kernel_class=RBF)
# Out:
#  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                   | 8/9 [09:00<02:03, 123.42s/it]2023-01-28 16:13:25.069284: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 131072000000 exceeds 10% of free system memory.
# 2023-01-28 16:13:33.163614: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 131072000000 exceeds 10% of free system memory.
# 2023-01-28 16:13:42.821905: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 131072000000 exceeds 10% of free system memory.
# 2023-01-28 16:13:59.457183: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 131072000000 exceeds 10% of free system memory.
# 2023-01-28 16:14:13.767462: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 131072000000 exceeds 10% of free system memory.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [16:53<00:00, 112.59s/it]

# %%
# # res_analytical = hd.compute_population_quantities([4096], bandwidth_order=1., kernel_class=RBF)

# tf.random.set_seed(1)
# delta = 2
# d = 4096
# npop = 4000
# target_dist, sample_dist = hd.generate_target_proposal(d, delta)
# X = sample_dist.sample((npop,))

# kernel = RBF(sigma_sq=2.*d**1.)
# ksd = KSD(kernel=kernel, log_prob=target_dist.log_prob)

# import time
# st = time.time()
# ksd_val = ksd(X, tf.identity(X)).numpy()
# et = time.time()
# print("total ellapsed time:", et - st)

# %%
# res_analytical2 = hd.compute_population_quantities([4096], bandwidth_order=1., kernel_class=RBF)

# %%
## save analytical res
# res_analytical_save = res_analytical
# res_analytical_save["dim"] = dims
# pd.DataFrame(res_analytical_save).to_csv(f"../res/high_dim/res_analytical_delta{DELTA}.csv", index=False)

## load analytical res
# res_analytical_save = pd.read_csv("../res/high_dim/res_analytical.csv")
# # res_analytical = res_analytical_save.to_dict()
# res_analytical = {c: res_analytical_save[c].to_list() for c in res_analytical_save.columns}
# dims = list(res_analytical["dim"])

# %%
tf.random.set_seed(2022)

# ns = [int(d) for d in dims]
# ns = [500] * len(dims)
# ns = [50] * len(dims)
ns = [10] * len(dims)

ksd_res = hd.compute_ksd(
    ns=ns,
    dims=dims,
    nreps=100,
    kernel_class=RBF,
    bandwidth_order=1.,
)
# Out:
# Repetition [100/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:16<00:00,  1.81s/it]

# %%
tf.random.set_seed(2022)

ns = [1000] * len(dims)

ksd_res_500 = hd.compute_ksd(
    ns=ns,
    dims=dims,
    nreps=100,
    kernel_class=RBF,
    bandwidth_order=1.,
)
# Out:
# Repetition [57/100:  44%|████████████████████████████████████████████████████████████████████                                                                                     | 4/9 [02:47<03:10, 38.05s/it]

# %%
ksd_res_500 = ksd_res_100

# %%
# # save a copy
# ksd_res_500 = ksd_res

# %% [markdown]
# # Quantile vs. dim

# %%
tf.random.set_seed(2022)

btsp_res = hd.bootstrap_quantile(
    dims=dims,
    ns=ns,
    num_boot=1000,
    nreps=100,
    kernel_class=RBF,
    bandwidth_order=1.,
)
# Out:
# [100 / 100]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:19<00:00,  2.20s/it]

# %%
q_res = [np.mean(btsp_res[d]) for d in dims]

figs, axes = plt.subplots(nrows=1, ncols=1)

axes.plot(dims, q_res, marker="x", label="Quantile", color="blue")
axes.plot(dims, res_analytical["ksd"], marker="x", label="KSD")
axes.set_xlabel("Dim")

axes.legend()

# %% [markdown]
# # Power vs. dim

# %%
ts_l = np.array(res_analytical["ksd"]) * (1 - 0.2)
# ts_l = q_res # use quantiles from indep samples
ts_u = np.array(res_analytical["ksd"]) * (1 + 0.2)

res = hd.power_experiment(
    ksd_res,
    res_analytical,
    ns,
    dims,
    ts_lb=ts_l,
    ts_ub=ts_u,
)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 6880.92it/s]

# %%
figs, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(res["dim"], res["probs_l"], marker="x", label="probability")
axes[0].plot(res["dim"], res["l_bd"], marker="x", label="bound")
axes[0].set_xlabel("Dim")
axes[0].set_ylim(-0.02, 1.02)
# axes[0].legend()
axes[0].set_title("lower bound")

axes[1].plot(res["dim"], res["probs_u"], marker="x", label="probability")
axes[1].plot(res["dim"], res["u_bd"], marker="x", label="bound")
axes[1].set_xlabel("Dim")
axes[1].set_ylim(-0.02, 1.02)
axes[1].legend()
axes[1].set_title("upper bound")
# Out:
# Text(0.5, 1.0, 'upper bound')

# %%
# BE bound
res_be = hd.power_experiment(
    ksd_res,
    res_analytical,
    ns,
    dims,
    ts_lb=ts_l,
    ts_ub=ts_u,
    bound="be",
)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 4257.70it/s]

# %%
figs, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(res_be["dim"], res_be["probs_l"], marker="x", label="Power", color="blue")
axes[0].plot(res["dim"], res["l_bd"], marker="^", label="Markov", color="orange")
axes[0].plot(res_be["dim"], res_be["l_bd"], marker="s", label="BE", color="green")
axes[0].set_xlabel("Dim", fontsize=15)
axes[0].set_ylabel("Probability", fontsize=15)
axes[0].set_title("Lower bound $t < D$", fontsize=15)
axes[0].set_ylim(-0.02, 1.02)
axes[0].tick_params(labelsize=15)

axes[1].plot(res_be["dim"], res_be["probs_u"], marker="x", label="Power", color="blue")
axes[1].plot(res["dim"], res["u_bd"], marker="^", label="Markov", color="orange")
axes[1].plot(res_be["dim"], res_be["u_bd"], marker="s", label="BE", color="green")
axes[1].set_xlabel("Dim", fontsize=15)
axes[1].set_title("Upper bound $t > D$", fontsize=15)
axes[1].set_ylim(-0.02, 1.02)
axes[1].tick_params(labelsize=15)
axes[1].legend(fontsize=15)
plt.tight_layout()

# figs.savefig("figs/power_dim.pdf")

# %% [markdown]
# # Fixed n, d, varying t

# %%
# i = -1
i = 1
d = dims[i]
print("dim chosen:", d)

res_analytical_d = {
    k: v[i] for k, v in res_analytical.items()
}

ts = res_analytical_d["ksd"] * np.linspace(0.75, 1.25, 101)
# Out:
# dim chosen: 16

# %%
print(f"d={d}")
print("cond_var \t", 4 * res_analytical_d["cond_var"])
print("full_var / n \t", 2 * res_analytical_d["full_var"] / ns[i])
print("sum_var / n \t", 4 * res_analytical_d["cond_var"] + 2 * res_analytical_d["full_var"] / ns[i])
# Out:
# d=16
# cond_var 	 10.62762451171875
# full_var / n 	 0.022344101901172506
# sum_var / n 	 10.649968613619922

# %%
hd_limits = hd.LimitDistExperiment(
    empirical_vals=ksd_res_500[d], # TODO ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts=ts,
)

# %%
res_probs = hd_limits.run("probs")

res_cond = hd_limits.run("cond")
res_full = hd_limits.run("full")
res_sum = hd_limits.run("sum")

res_mm_full = hd_limits.run("mm_full")

# %%
figs, axes = plt.subplots(nrows=1, ncols=1)

# empirical probs
axes.plot(hd_limits.ts, res_probs["probs"], marker="x", label="Empirical")

# norm cond bound
axes.plot(hd_limits.ts, res_cond["probs"], marker="v", label="Cond")

# norm full bound
axes.plot(hd_limits.ts, res_full["probs"], marker="v", label="Full")

# # norm sum bound
# axes.plot(hd_limits.ts, res_sum["probs"], marker=".", label="Sum")

# statistic expectation
axes.axvline(hd_limits.res_analytical["ksd"], color="k", linestyle="--", label="KSD")

axes.set_xlabel("Decision threshold $t$", fontsize=15)
axes.set_ylabel("Probability", fontsize=15)
# axes.set_xlim(1., 2.4)
axes.set_ylim(0., 1.)
axes.tick_params(labelsize=15)
axes.legend(fontsize=14)

# %%
figs, axes = plt.subplots(nrows=1, ncols=1)

# empirical probs
axes.plot(hd_limits.ts, res_probs["probs"], marker="x", label="Empirical")

# normal full bound
axes.plot(hd_limits.ts, res_full["probs"], label="Normal Full", color="C2")

# MM full bound
axes.plot(hd_limits.ts, res_mm_full["probs"], label="MM Full", color="C4")

# statistic expectation
axes.axvline(hd_limits.res_analytical["ksd"], color="k", linestyle="--", label="KSD")

axes.set_xlabel("Decision threshold $t$", fontsize=15)
axes.set_ylabel("Probability", fontsize=15)
axes.set_ylim(0., 1.)
axes.tick_params(labelsize=15)
axes.legend(fontsize=14)

# %% [markdown]
# # Fixed n, d, varying t

# %%
i = -1
d = dims[i]
print("dim chosen:", d)

res_analytical_d = {
    k: v[i] for k, v in res_analytical.items()
}

ts_l = res_analytical_d["ksd"] * (1 - np.linspace(0., 0.9, 51))
ts_u = res_analytical_d["ksd"] * (1 + np.linspace(0., 0.9, 51))

res = hd.power_experiment_t(
    ksd_vals=ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts_lb=ts_l,
    ts_ub=ts_u,
)
# Out:
# dim chosen: 256
#   0%|                                                                                                                                                                                   | 0/51 [00:00<?, ?it/s]/data/xl6116/github/pksd/high_dim/high_dim_power.py:193: RuntimeWarning: divide by zero encountered in true_divide
#   m2 / (n * (t_lb - ksd)**2) +
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:194: RuntimeWarning: divide by zero encountered in double_scalars
#   M2 / (n * (n - 1) * ((t_lb - ksd)**2))
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:197: RuntimeWarning: divide by zero encountered in true_divide
#   m2 / (n * (t_ub - ksd)**2) +
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   M2 / (n * (n - 1) * ((t_ub - ksd)**2))
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 22944.28it/s]

# %%
# Berry-Esseen
res_be = hd.power_experiment_t(
    ksd_vals=ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts_lb=ts_l,
    ts_ub=ts_u,
    bound="be",
)
# Out:
#   0%|                                                                                                                                                                                   | 0/51 [00:00<?, ?it/s]/data/xl6116/github/pksd/high_dim/high_dim_power.py:214: RuntimeWarning: divide by zero encountered in true_divide
#   m2 / (n*(n - 1) * (t_ub - ksd)**2) +
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:215: RuntimeWarning: divide by zero encountered in double_scalars
#   M2**0.5 * m2 / (n**(3/2) * (n - 1)**0.5 * (t_ub - ksd)**3) +
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:216: RuntimeWarning: divide by zero encountered in true_divide
#   m3 / (n**2 * (t_ub - ksd)**3)
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:221: RuntimeWarning: divide by zero encountered in true_divide
#   m2 / (n*(n - 1) * (t_lb - ksd)**2) +
# /data/xl6116/github/pksd/high_dim/high_dim_power.py:222: RuntimeWarning: divide by zero encountered in double_scalars
#   M2**0.5 * m2 / (n**(3/2) * (n - 1)**0.5 * np.abs(t_lb - ksd)**3) +
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 4420.53it/s]

# %%
# new surrogate full
res_new_full = hd.power_experiment_t(
    ksd_vals=ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts_lb=ts_l,
    ts_ub=ts_u,
    bound="new_full",
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 5322.59it/s]

# %%
# new surrogate cond
res_new_cond = hd.power_experiment_t(
    ksd_vals=ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts_lb=ts_l,
    ts_ub=ts_u,
    bound="new_cond",
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 5339.99it/s]

# %%
# new surrogate sum
res_new_sum = hd.power_experiment_t(
    ksd_vals=ksd_res[d],
    res_analytical=res_analytical_d,
    n=ns[i],
    ts_lb=ts_l,
    ts_ub=ts_u,
    bound="new_sum",
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 5084.49it/s]

# %%
# moment matching

# %%
figs, axes = plt.subplots(nrows=1, ncols=1)

# empirical probs
axes.plot(res_be["t_l"], res_be["probs_l"], marker="x", label="Power", color="blue")
axes.plot(res["t_u"], res["probs_u"], marker="x", color="blue")

# new cond bound
axes.plot(res_new_cond["t_l"], res_new_cond["l_bd"], marker="v", label="Cond", color="grey")
axes.plot(res_new_cond["t_u"], res_new_cond["u_bd"], marker="v", color="grey")

# new full bound
axes.plot(res_new_full["t_l"], res_new_full["l_bd"], marker="v", label="Full", color="red")
axes.plot(res_new_full["t_u"], res_new_full["u_bd"], marker="v", color="red")

# new sum bound
axes.plot(res_new_sum["t_l"], res_new_sum["l_bd"], marker=".", label="Sum", color="purple")
axes.plot(res_new_sum["t_u"], res_new_sum["u_bd"], marker=".", color="purple")


axes.axvline(res_analytical_d["ksd"], color="k", linestyle="--", label="KSD")

axes.set_xlabel("Decision threshold $t$", fontsize=15)
axes.set_ylabel("Probability", fontsize=15)
# axes.set_xlim(1., 2.4)
axes.set_ylim(0., 1.)
axes.tick_params(labelsize=15)
axes.legend(fontsize=14)

# figs.savefig("figs/power_t.pdf")

# %%
print(f"d={d}")
print(res_analytical_d["cond_var"])
print(res_analytical_d["full_var"])
# Out:
# d=256
# 2.3329563
# 37.57206252960896

# %%
print(f"d={d}")
print("cond_var \t", res_analytical_d["cond_var"])
print("full_var / n \t", res_analytical_d["full_var"] / ns[i])
# Out:
# d=256
# cond_var 	 2.3329563
# full_var / n 	 0.7514412505921791

# %%
figs, axes = plt.subplots(nrows=1, ncols=1)

# empirical probs
axes.plot(res_be["t_l"], res_be["probs_l"], marker="x", label="Power", color="blue")
axes.plot(res["t_u"], res["probs_u"], marker="x", color="blue")

# markov bound
axes.plot(res["t_l"], res["l_bd"], marker="^", label="Markov", color="orange")
axes.plot(res["t_u"], res["u_bd"], marker="^", color="orange")

# BE bound
axes.plot(res_be["t_l"], res_be["l_bd"], marker="s", label="BE", color="green")
axes.plot(res_be["t_u"], res_be["u_bd"], marker="s", color="green")

# new cond bound
axes.plot(res_new_cond["t_l"], res_new_cond["l_bd"], marker="v", label="Cond", color="grey")
axes.plot(res_new_cond["t_u"], res_new_cond["u_bd"], marker="v", color="grey")

# new full bound
axes.plot(res_new_full["t_l"], res_new_full["l_bd"], marker="v", label="Full", color="red")
axes.plot(res_new_full["t_u"], res_new_full["u_bd"], marker="v", color="red")

# new sum bound
axes.plot(res_new_sum["t_l"], res_new_sum["l_bd"], marker=".", label="Sum", color="purple")
axes.plot(res_new_sum["t_u"], res_new_sum["u_bd"], marker=".", color="purple")

axes.axvline(res_analytical_d["ksd"], color="k", linestyle="--", label="KSD")

axes.set_xlabel("Decision threshold $t$", fontsize=15)
axes.set_ylabel("Probability", fontsize=15)
# axes.set_xlim(1., 2.4)
axes.set_ylim(0., 1.)
axes.tick_params(labelsize=15)
axes.legend(fontsize=14)
axes.set_title(f"dim = {d}")

# figs.savefig("figs/power_t.pdf")
# Out:
# Text(0.5, 1.0, 'dim = 2048')

# %% [markdown]
# # Moments vs. dim

# %%
ksd_vals = np.array(res_analytical["ksd"])
m2_vals = np.array(res_analytical["cond_var"])
M2_vals = np.array(res_analytical["full_var"])
m3_vals = np.array(res_analytical["m3"])

m2_d2 = m2_vals / ksd_vals**2
M2_d2 = M2_vals / ksd_vals**2
m3_d3 = m3_vals / ksd_vals**3

figs, axes = plt.subplots(nrows=1, ncols=4, figsize=(12, 3))

axes[0].plot(dims, ksd_vals, marker="x", label="$m_2 / D^2$", color="blue")
axes[0].set_xlabel("Dim", fontsize=15)
axes[0].set_ylabel("KSD", fontsize=15)
axes[0].set_ylim(1.3, 2.)
axes[0].tick_params(labelsize=15)

axes[1].plot(dims, m2_vals, marker="x", label="$m_3 / D^3$", color="blue")
axes[1].set_xlabel("Dim", fontsize=15)
axes[1].set_ylabel("$m_2$", fontsize=15)
axes[1].tick_params(labelsize=15)

axes[2].plot(dims, m3_vals, marker="x", label="$m_3 / D^3$", color="blue")
axes[2].set_xlabel("Dim", fontsize=15)
axes[2].set_ylabel("$m_3$", fontsize=15)
axes[2].tick_params(labelsize=15)

axes[3].plot(dims, M2_vals, marker="x", label="$M_2 / D^2$", color="blue")
axes[3].set_xlabel("Dim", fontsize=15)
axes[3].set_ylabel("$M_2$", fontsize=15)
axes[3].tick_params(labelsize=15)

plt.tight_layout()

# figs.savefig("figs/moments_dim.pdf")

# %% [markdown]
# # Kernels

# %%
from src.ksd.kernel import RBF, IMQ
import seaborn as sns
import pandas as pd

# %%
xx = tf.expand_dims(tf.linspace(-6., 6., 100), -1)
yy = tf.zeros((100, 1))

# %%
bandwidths = [0.1, 1., 5., 10.]
kk_all = []

figs, axes = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))
for b in bandwidths:
    k_rbf = RBF(sigma_sq=tf.constant(b))
    kk_rbf = k_rbf(xx, yy)[:, 0].numpy()

    k_imq = IMQ(sigma_sq=tf.constant(b))
    kk_imq = k_imq(xx, yy)[:, 0].numpy()
    
    plot_xx = xx[:, 0]
    axes[0].plot(xx, kk_rbf, label=f"$\gamma$={b}")
    axes[1].plot(xx, kk_imq, label=f"$\gamma$={b}")
    
axes[1].legend()

# %%
bandwidths = [0.1, 1., 5., 10.]
xx_plot = xx[:, 0]
res_rbf = {"x": [], "y": [], "b": []}
res_imq = {"x": [], "y": [], "b": []}

for b in bandwidths:
    k_rbf = RBF(sigma_sq=tf.constant(b))
    kk_rbf = k_rbf(xx, yy)[:, 0].numpy()

    k_imq = IMQ(sigma_sq=tf.constant(b))
    kk_imq = k_imq(xx, yy)[:, 0].numpy()
        
    res_rbf["x"] += list(xx_plot.numpy())
    res_rbf["y"] += list(kk_rbf)
    res_rbf["b"] += [b] * len(xx_plot)
    
    res_imq["x"] += list(xx_plot.numpy())
    res_imq["y"] += list(kk_imq)
    res_imq["b"] += [b] * len(xx_plot)
    
res_rbf = pd.DataFrame(res_rbf)
res_imq = pd.DataFrame(res_imq)

figs, axes = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))

sns.lineplot(ax=axes[0], data=res_rbf, x="x", y="y", hue="b")
axes[0].legend(title="$\gamma$")
axes[0].set_xlabel(f"$|| x - y ||_2^2$", fontsize=15)
axes[0].set_ylabel("")

sns.lineplot(ax=axes[1], data=res_imq, x="x", y="y", hue="b")
axes[1].legend([],[], frameon=False)
axes[1].set_xlabel(f"$|| x - y ||_2^2$", fontsize=15)
axes[1].set_ylabel("")

plt.tight_layout()

# %%
plt.figure()
sns.lineplot(data=res_rbf, x="x", y="y", hue="b")
plt.legend(title="$\gamma$")
plt.xlabel(f"$|| x - y ||_2^2$", fontsize=15)
plt.ylabel("")
plt.savefig("figs/rbf.pdf")

plt.figure()
sns.lineplot(data=res_imq, x="x", y="y", hue="b")
plt.legend([],[], frameon=False)
plt.xlabel(f"$|| x - y ||_2^2$", fontsize=15)
plt.ylabel("")
plt.savefig("figs/imq.pdf")
