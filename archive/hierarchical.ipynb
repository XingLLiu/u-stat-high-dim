# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy.stats import norm, energy_distance
import multiprocessing

import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
import tensorflow.experimental.numpy as tnp
tnp.experimental_enable_numpy_behavior()

import sys
sys.path.append(".")
from src.dc_smc import dc_smc 
from src.model import Model
from src.utils import resample, weighted_sum, effective_sample_size

from geomloss import SamplesLoss
import torch

energy_distance = SamplesLoss("energy")

# %%
import numpy as np
import matplotlib.pyplot as plt

delta = 0.02
w1 = 0.5

def f_a(w, theta):
    term1 = (1 - theta) * (1 + 1/theta) * (1 - w)**(1 / theta)
    term2 = theta * (1 + 1 / (1 - theta)) * w**(1 / (1 - theta))
    return term1 + term2

def f_b(w, theta):
    if theta < 0.999:
        z = 1 - (1 - 1e-9) * (
            (1 - theta) * (1 - w1 - delta/2)**(1/theta + 1) \
            + theta * (w1 + delta/2)**(1 / (1-theta) + 1) \
            - (1 - theta) * (1 - w1 + delta/2)**(1/theta + 1) \
            - theta * (w1 - delta/2)**(1 / (1 - theta) + 1)
        )
        ind2 = (w > (w1 - delta/2)) & (w < (w1 + delta/2))
        ind1 = 1 - ind2
        return f_a(w, theta) / z * (ind1 + 1e-9 * ind2)
    if theta >= 0.999:
        return f_a(w, theta)


xx = np.arange(0, 1, 0.001)
theta_list = [0.2, 0.4, 0.6, 0.8]

plt.figure(figsize=(12, 3))
for i, theta in enumerate(theta_list):
    plt.subplot(1, 4, i+1)
    yy = f_a(xx, theta)
    plt.plot(xx, yy)
    plt.ylim((-0.2, None))
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.title(f"$\\theta = {theta}$", fontsize=18)
    plt.xlabel("$w$", fontsize=15)
    plt.ylabel("$f^a(w; \\theta)$", fontsize=15)
plt.savefig("figs/density_fa.pdf")

plt.figure(figsize=(12, 3))
for i, theta in enumerate(theta_list):
    plt.subplot(1, 4, i+1)
    yy = f_b(xx, theta)
    plt.plot(xx, yy)
    plt.ylim((-0.2, None))
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.title(f"$\\theta = {theta}$", fontsize=18)
    plt.xlabel("$w$", fontsize=15)
    plt.ylabel("$f^b(w; \\theta)$", fontsize=15)
plt.tight_layout()
plt.savefig("figs/density_fb.pdf")

# %%
plt.figure(figsize=(5, 7.5))
plt.subplot(2, 1, 1)
theta_list = np.arange(0, 1, 0.0001)[1:]
yy = [0] * len(theta_list)
for i in range(len(yy)):
    yy[i] = f_a(w1, theta_list[i])
plt.plot(theta_list, yy)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.xlabel("$\\theta$", fontsize=19)
plt.ylabel("$f^a(w_1; \\theta)$", fontsize=19)
plt.tight_layout()

# plt.figure(figsize=(3, 3))
plt.subplot(2, 1, 2)
theta_list = np.arange(0, 1, 0.0001)[-100:]
yy = [0] * len(theta_list)
for i in range(len(yy)):
    yy[i] = f_b(w1, theta_list[i])
plt.plot(theta_list, yy)
# plt.ylim((-0.2, None))
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
plt.xlabel("$\\theta$", fontsize=19)
plt.ylabel("$f^b(w_1; \\theta)$", fontsize=19)
plt.tight_layout()
plt.savefig("figs/unnormalised_posteriors.pdf")

# %%
def plot_hist(ind, samples_plot, samples_init=None, label1=None, label2=None):
    label1 = f"final x{ind}" if label1 is None else label1
    label2 = f"initial x{ind}" if label2 is None else label2
    
    sns.histplot(tf.reshape(samples_plot[:, ind], -1), stat="density", color="r", alpha=0.4, label=label1)
    if samples_init is not None:
        sns.histplot(tf.reshape(samples_init[:, ind], -1), stat="density", alpha=0.4, label=label2)
    ymax = plt.ylim()[1]
    plt.vlines(x_true[0, ind], 0, ymax, color="orange", label="true mu")
    plt.ylim(0, ymax)
    x_plot = np.linspace(2, 4, 500)
    plt.legend()
    plt.show()

    print(
        f"true x_{ind+1}:",
        x_true[0, ind],
        "\nestimate:",
        tf.reduce_mean(samples_plot[:, ind])
    )

# %%
def IS_augmented_experiment(
    h_dist, 
    h_tilde_dist, 
    log_target_old,
    log_target_new,
    log_target_aug_old,
    log_target_aug_new,
    init_samples, 
    true_samples=None, 
    plot=True, 
    ind=0
):
    """Augmented base and target distributions
        log_target_old: log_prob function for old target
        log_target_new: log_prob function for new target
        init_samples: unaugmented base samples
    """
    h_samples = h_dist.sample((1,)).T
    base_samples = tf.concat([init_samples, h_samples], axis=1)

    log_w = (
        log_target_aug_new(base_samples, log_target_new, h_tilde_dist) 
        - log_target_aug_old(base_samples, log_target_old, h_dist)
    )
    
    samples_plot = resample(log_w, base_samples)
    # discard dummy variable
    samples_plot = samples_plot[:, :init_samples.shape[1]]

    # compute ESS
    ess = effective_sample_size(log_w)
    
    # plot
    if plot:
        plot_hist(ind, samples_plot, true_samples, label1="IS augment", label2="HMC new")

    if true_samples is not None:
        energy_dist = energy_distance(
            torch.Tensor(samples_plot.numpy()),
            torch.Tensor(true_samples.numpy())
        )
        return ess, energy_dist
    else:
        return ess

# %%
def run_dcsmc_experiment(dcsmc_model, init_samples, true_samples, nrep):
    ess_list = -1 * np.ones(nrep)
    energy_list = -1 * np.ones_like(ess_list)
    
    for i in range(nrep):
        if i % 10 == 0:
            print(f"Running repetition [{i} / {nrep}]")

        # initialize samples and weights
        init_samples = tf.Variable(init_samples)

        log_w_init = np.ones_like(init_samples)
        log_w_init = tf.Variable(log_w_init)

        # run D&C SMC
        samples_res, log_w = dc_smc(init_samples, log_w_init, model)

        # compute ESS
        ess = effective_sample_size(log_w)
        
        # resample from weighted empirical distribution
        # for D&C SMC, only need to resample the root node
#         samples_plot = tf.Variable(tf.identity(samples_res))
#         samples_plot = samples_plot[:, -1].assign(resample(log_w, samples_res[:, -1]))
        samples_plot = tf.Variable(resample(log_w, samples_res))

        # compute energy distance
        energy_dist = energy_distance(
            torch.Tensor(samples_plot.numpy()),
            torch.Tensor(true_samples.numpy())
        )

        ess_list[i] = ess
        energy_list[i] = energy_dist
        
    return ess_list, energy_list, samples_plot

# %% [markdown]
# # 5-var model

# %% [markdown]
# Target:
# $$
# y_i | x_i \sim \mathcal{N}(x_i, \sigma^2), i = 1, 2, 3 \\
# x_i | x_4 \sim \mathcal{N}(x_4, \tau^2), i = 1, 2 \\
# x_i | x_5 \sim \mathcal{N}(x_t, \gamma^2), i = 3, 4
# $$
# Priors:
# $$
# x_i \sim \mathcal{N}(\mu_0, \sigma_0^2), i = 1, 2, \ldots, 5
# $$

# %%
tf.random.set_seed(1)

N = 2000 # num params samples
nobs = 1 # 1000 # num observations

sigma, tau, gamma = np.array([1.]), np.array([1.]), np.array([1.])
mu0, sigma0 = np.array([0.]), np.array([1.])

x5 = np.array([-1.])
x4, x3 = tfd.Normal(loc=x5, scale=gamma).sample(2)
x1, x2 = tfd.Normal(loc=x4, scale=tau).sample(2)
x_true = tf.reshape(tf.concat([x1, x2, x3, x4, x5], axis=0), (1, -1))

# %%
# simulate data
y1 = tfd.Normal(loc=x_true[:, 0], scale=sigma).sample((nobs, 1))
y2 = tfd.Normal(loc=x_true[:, 1], scale=sigma).sample((nobs, 1))
y3 = tfd.Normal(loc=x_true[:, 2], scale=sigma).sample((nobs, 1))
obs = tf.concat([y1, y2, y3], axis=1)[:, :, 0]
# obs = tf.concat([y1, y2, y3], axis=1)
# obs = tf.transpose(obs, perm=[0, 2, 1])

# %%
def init_target(obs, mean_shift=0):
    def log_gamma1(x):
        loglik = tfd.Normal(loc=x[:, :1], scale=sigma).log_prob(obs[:, :1].T)
        loglik = tf.reduce_sum(loglik, axis=1, keepdims=True)
        logprior = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, :1])
        return loglik + logprior

    def log_gamma2(x):
        loglik = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
        loglik = tf.reduce_sum(loglik, axis=1, keepdims=True)
        logprior = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 1:2])
        return loglik + logprior

    def log_gamma3(x):
        loglik = tfd.Normal(loc=x[:, 2:3], scale=sigma).log_prob(obs[:, 2:3].T)
        loglik = tf.reduce_sum(loglik, axis=1, keepdims=True)
        logprior = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 2:3])
        return loglik + logprior

    def log_gamma4(x):
        loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, :1].T)
        loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
        loglik = tf.reduce_sum(loglik1 + loglik2, axis=1, keepdims=True)
        logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
        logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])
        logp4 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 3:4])
        return loglik + logp1 + logp2 + logp4

    def log_gamma5(x):
        loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, :1].T)
        loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
        loglik3 = tfd.Normal(loc=x[:, 2:3], scale=sigma).log_prob(obs[:, 2:3].T)
        loglik = tf.reduce_sum(loglik1 + loglik2 + loglik3, axis=1, keepdims=True)
        
        logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, :1])
        logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
        logp3 = tfd.Normal(loc=x[:, 4:5] + mean_shift, scale=gamma).log_prob(x[:, 2:3])
        logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
        logp5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
        return loglik + logp1 + logp2 + logp3 + logp4 + logp5
    return log_gamma1, log_gamma2, log_gamma3, log_gamma4, log_gamma5

# %%
class Proposal:
    def __init__(self):
        self.dist = tfd.Normal(np.zeros(1), np.ones(1))
    def log_prob(self, mu_new, mu_curr):
        return self.dist.log_prob(mu_new) # nsample x dim
    def sample(self, size, mu_curr):
        return self.dist.sample(size)[:, :, 0]

# %%
proposal = Proposal()
log_gamma1, log_gamma2, log_gamma3, log_gamma4, log_gamma5 = init_target(obs)

model = Model(log_gamma5, proposal, 4)
model.build_child(log_gamma4, proposal, 3)
model.build_child(log_gamma3, proposal, 2)
model.children[0].build_child(log_gamma2, proposal, 1)
model.children[0].build_child(log_gamma1, proposal, 0)

# %%
# initialize samples from N(0, 1)
samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N, x_true.shape[1]))[:, :, 0]
samples_init = tf.Variable(samples_plot_init)

# initialize weights
log_w_init = np.ones_like(samples_init)
log_w_init = tf.Variable(log_w_init)

# %%
samples_res, log_w = dc_smc(samples_init, log_w_init, model)

# %%
samples_plot = tf.Variable(tf.identity(samples_res))
samples_plot = samples_plot[:, -1].assign(resample(log_w, samples_res[:, -1]))
# samples_plot[:, -1] = resample(log_w, samples_res[:, -1])
# samples_plot = tf.convert_to_tensor(samples_plot)

# %%
plot_hist(4, samples_plot, samples_plot_init)

# %% [markdown]
# ### Compare with results from SMC

# %%
def loglik(x):
    loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, 0:1].T)
    loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
    loglik3 = tfd.Normal(loc=x[:, 2:3], scale=sigma).log_prob(obs[:, 2:3].T)
    loglik = tf.reduce_sum(loglik1 + loglik2 + loglik3, axis=1, keepdims=True)
    return loglik

def logprior(x):
    logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
    logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
    logp3 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 2:3])
    logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
    logprior5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
    return logp1 + logp2 + logp3 + logp4 + logprior5
    
def log_target(x):
#     return (logprior(x) + loglik(x)).reshape()
    return logprior(x) + loglik(x)

def smc(seed):
    return tfp.experimental.mcmc.sample_sequential_monte_carlo(
        prior_log_prob_fn=logprior,
        likelihood_log_prob_fn=loglik,
        current_state=samples_init,
        seed=seed)[1]

# %%
smc_res = smc(seed=(12, 34))

# %%
ind = 4
plot_hist(ind, smc_res, samples_plot, label1="SMC", label2="DC SMC")

print(
    f"true x{ind+1}:",
    x_true[0, ind],
    "\nHMC estimate:",
    tf.reduce_mean(smc_res[:, ind]),
    "\nDC SMC estimate:",
    weighted_sum(lambda x: x, samples_res[:, ind].reshape((-1, 1)), log_w)
)

# %% [markdown]
# # Change prior
# $p_3(x_3) = \mathcal{N}(x_3; 0, \gamma^2) \rightarrow p_3(x_3) = \mathcal{N}(x_3; 0, 4\gamma^2)$

# %%
def log_gamma5_new(x):
    loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, :1].T)
    loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
    loglik3 = tfd.Normal(loc=x[:, 2:3], scale=sigma).log_prob(obs[:, 2:3].T)
    loglik = tf.reduce_sum(loglik1 + loglik2 + loglik3, axis=1, keepdims=True)

    logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, :1])
    logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
    logp3 = tfd.Normal(loc=x[:, 4:5], scale=2 * gamma).log_prob(x[:, 2:3])
    logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
    logp5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
    return loglik + logp1 + logp2 + logp3 + logp4 + logp5

# %%
model_new = Model(log_gamma5_new, proposal, 4)
model_new.build_child(log_gamma4, proposal, 3, update=False)
model_new.build_child(log_gamma3, proposal, 2, update=False)
model_new.children[0].build_child(log_gamma2, proposal, 1, update=False)
model_new.children[0].build_child(log_gamma1, proposal, 0, update=False)

# %%
samples_res_new, log_w_new = dc_smc(samples_res, log_w, model_new)

# %%
samples_plot_new = tf.Variable(tf.identity(samples_res_new))
samples_plot_new = samples_plot_new[:, -1].assign(resample(log_w, samples_res_new[:, -1]))

# %%
plot_hist(4, samples_plot_new, samples_plot)

# %% [markdown]
# ## Compare new samples with HMC

# %%
def logprior_new(x):
    logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
    logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
    logp3 = tfd.Normal(loc=x[:, 4:5], scale=2 * gamma).log_prob(x[:, 2:3])
    logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
    logprior5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
    return logp1 + logp2 + logp3 + logp4 + logprior5

def log_target_new(x):
    return (logprior_new(x) + loglik(x)).reshape()

# %%
smc_res_new = tfp.experimental.mcmc.sample_sequential_monte_carlo(
    prior_log_prob_fn=logprior_new,
    likelihood_log_prob_fn=loglik,
    current_state=samples_init,
    seed=(12, 34))[1]

# %%
ind = 4
plot_hist(ind, smc_res_new, samples_plot_new, label1="SMC", label2="DC SMC")

print(
    f"true x{ind+1}:",
    x_true[0, ind],
    "\nHMC estimate:",
    weighted_sum(lambda x: x, smc_res_new[:, ind].reshape((-1, 1))),
    "\nDC SMC estimate:",
    weighted_sum(lambda x: x, samples_res_new[:, ind].reshape((-1, 1)), log_w_new)
)

# %% [markdown]
# # MCMC starting from a point in current samples

# %%
mcmc_init = tf.identity(samples_init[:1, :])

mcmc_res = tfp.mcmc.sample_chain(
  num_results=1000,
  current_state=tf.zeros_like(mcmc_init), # mcmc_init,
  kernel=tfp.mcmc.RandomWalkMetropolis(log_target),
  num_burnin_steps=500,
  trace_fn=None,
  seed=42)

# %%
mcmc_res[:, :, 0]

# %% [markdown]
# # Augmented base and target

# %% [markdown]
# ## 1. x = {x_1, x_2, x_4}, y = {x_5}, z = {x_3}

# %% [markdown]
# $p(x_3 | x_5) = \mathcal{N}(x_3; x_5, \gamma^2) \rightarrow p(x_3 | x_5) = \mathcal{N}(x_3; x_5 + 2, \gamma^2)$

# %%
def log_target(x):
    return logprior(x) + loglik(x)

def logprior_new(x):
    logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
    logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
    logp3 = tfd.Normal(loc=x[:, 4:5] + 2, scale=gamma).log_prob(x[:, 2:3])
    logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
    logprior5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
    return logp1 + logp2 + logp3 + logp4 + logprior5

def log_target_new(x):
    return logprior_new(x) + loglik(x)

# %%
# proposal distribution h
# class Proposal:
#     def __init__(self, mean=None, sd=None, N=None):
#         self.mean = np.zeros(N) if mean is None else mean
#         self.sd = np.ones(N) if sd is None else sd
#         self.dist = tfd.Normal(self.mean, self.sd)
#     def log_prob(self, mu_new):
#         return self.dist.log_prob(mu_new).reshape((-1, 1)) # nsample x dim
#     def sample(self, size):
#         return self.dist.sample(size).T

class Proposal:
    """Needs to be a multivariate distribution instead of univariate in order
    to ensure the dimensionality of log_prob is 1 x nsample. This is corrected
    in log_base_augment(), IS_augmented_experiment(), log_base_augment(),
    and log_target_new_augment()
    """
    def __init__(self, mean=None, sd=None, N=None):
        self.mean = np.zeros(N) if mean is None else mean
        self.sd = np.ones(N) if sd is None else sd
        self.dist = tfd.Normal(self.mean, self.sd)
    def log_prob(self, mu_new):
        return self.dist.log_prob(mu_new) # 1 x nsample
    def sample(self, size):
        return self.dist.sample(size)

# %%
N = 2000
N_true = 2000

# %%
# given samples from old target
samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N_true, x_true.shape[1]))[:, :, 0]
samples_init = tf.Variable(samples_plot_init)

smc_res = tfp.experimental.mcmc.sample_sequential_monte_carlo(
    prior_log_prob_fn=logprior,
    likelihood_log_prob_fn=loglik,
    current_state=samples_init,
    seed=(12, 34))[1]

# %%
# get samples from new target (unavailable in practice)
samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N_true, x_true.shape[1]))[:, :, 0]
samples_init = tf.Variable(samples_plot_init)

smc_res_new = tfp.experimental.mcmc.sample_sequential_monte_carlo(
    prior_log_prob_fn=logprior_new,
    likelihood_log_prob_fn=loglik,
    current_state=samples_init,
    seed=(12, 34))[1]

# %%
# visualize old and new targets
for i in range(5):
    plot_hist(i, smc_res_new, smc_res, label1="HMC new", label2="HMC old")
# Out:
# true x_1: tf.Tensor(1.6739499345270943, shape=(), dtype=float64)
# estimate: tf.Tensor(1.2617588492028973, shape=(), dtype=float64)
# true x_2: tf.Tensor(-0.8109232714986124, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.23637004110411347, shape=(), dtype=float64)
# true x_3: tf.Tensor(0.4399671454377567, shape=(), dtype=float64)
# estimate: tf.Tensor(1.0467364515921571, shape=(), dtype=float64)
# true x_4: tf.Tensor(-0.5540992987520248, shape=(), dtype=float64)
# estimate: tf.Tensor(0.23846845950596504, shape=(), dtype=float64)
# true x_5: tf.Tensor(-1.0, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.26175196608956436, shape=(), dtype=float64)

# %% [markdown]
# ## Augmented Improtance Sampling

# %%
def log_base_augment(x, log_target, h_dist):
    log_p_target = log_target(x[:, :5])
    log_p_h = h_dist.log_prob(x[:, 5]).reshape((-1, 1))
    return log_p_target + log_p_h

def log_target_new_augment(x, log_target_new, h_tilde_dist):
    x_tilde = tf.Variable(tf.identity(x))
    x_tilde[:, 2].assign(x[:, 5])
    x_tilde[:, 5].assign(x[:, 2])
    
    log_p_target_new = log_target_new(x_tilde[:, :5])
    log_p_htilde = h_tilde_dist.log_prob(x_tilde[:, 5]).reshape((-1, 1))
    return log_p_target_new + log_p_htilde

# %% [markdown]
# ### Change sd

# %%
sd_list = [0.1, 1, 2, 5, 10]
nrep = 100

ess_list = -1 * np.ones((nrep, len(sd_list)))
energy_list = -1 * np.ones_like(ess_list)

# for constructing h_tilde
x3_mean = tf.math.reduce_mean(smc_res[:, 2])
x3_var = tf.math.reduce_variance(smc_res[:, 2])

for j, sd in enumerate(sd_list):
    print(f"Running for sd = {sd}")
    
    h_dist = Proposal(sd=np.ones(N)*sd)
#     h_tilde_dist = Proposal(N=N)
    h_tilde_dist = tfd.Laplace(
        loc=tf.ones(N) * x3_mean,
        scale=tf.ones(N) * x3_var
    )
    
    for i in range(nrep):
        ess, energy_dist = IS_augmented_experiment(
            h_dist=h_dist, 
            h_tilde_dist=h_tilde_dist, 
            log_target_old=log_target,
            log_target_new=log_target_new,
            log_target_aug_old=log_base_augment,
            log_target_aug_new=log_target_new_augment,
            init_samples=smc_res[:N, :], 
            true_samples=smc_res_new, 
            plot=False)
        ess_list[i, j] = ess
        energy_list[i, j] = energy_dist
# Out:
# Running for sd = 0.1
# Running for sd = 1
# Running for sd = 2
# Running for sd = 5
# Running for sd = 10

# %%
fig = plt.figure()

plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)
_ = plt.xticks(range(1, 1 + len(sd_list)), sd_list)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("$\sigma_q$", fontsize=15)
plt.ylabel("Effective Sample Size", fontsize=15)

plt.subplot(1, 2, 2)
_ = plt.plot(range(len(sd_list)), np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between(range(len(sd_list)),
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)
_ = plt.xticks(range(len(sd_list)), sd_list)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("$\sigma_q$", fontsize=15)
plt.ylabel("Energy Distance", fontsize=15)
fig.tight_layout()
plt.savefig("figs/ais_sd.pdf")

# 95% CI
print("mean", ess_list[:, 1].mean())
print("sd", ess_list[:, 1].std())
print("95%-CI", np.percentile(ess_list[:, 1], [2.5, 97.5]))
print("mean energy", energy_list[:, 1].mean())
print("sd energy", energy_list[:, 1].std())
# Out:
# mean 363.9146741659308
# sd 39.49548242410119
# 95%-CI [289.37871277 433.78731442]
# mean energy 0.12372664213180543
# sd energy 0.013140827206661525

# %%
ess_list.shape
# Out:
# (100, 5)

# %% [markdown]
# Check source of loss in quality

# %%
def log_base_augment(x, log_target, h_dist):
    log_p_target = log_target(x[:, :5])
    return log_p_target

def log_target_new_augment(x, log_target_new, h_tilde_dist):
    x_tilde = tf.Variable(tf.identity(x))
    x_tilde[:, 2].assign(x[:, 5])
    x_tilde[:, 5].assign(x[:, 2])

    logp1 = tfd.Normal(loc=x_tilde[:, 3:4], scale=tau).log_prob(x_tilde[:, 0:1])
    logp2 = tfd.Normal(loc=x_tilde[:, 3:4], scale=tau).log_prob(x_tilde[:, 1:2])   
    logp4 = tfd.Normal(loc=x_tilde[:, 4:5], scale=gamma).log_prob(x_tilde[:, 3:4])
    logprior5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x_tilde[:, 4:5])
    logp = logp1 + logp2 + logp4 + logprior5
    
    loglik1 = tfd.Normal(loc=x_tilde[:, 0:1], scale=sigma).log_prob(obs[:, 0:1].T)
    loglik2 = tfd.Normal(loc=x_tilde[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
    loglik = tf.reduce_sum(loglik1 + loglik2, axis=1, keepdims=True)
    
    log_p_htilde = h_tilde_dist.log_prob(x_tilde[:, 5]).reshape((-1, 1))
    
    res = logp + loglik + log_p_htilde

#     logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
#     logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
#     logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
#     logprior5 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x[:, 4:5])
#     logp = logp1 + logp2 + logp4 + logprior5
    
#     loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, 0:1].T)
#     loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
#     loglik = tf.reduce_sum(loglik1 + loglik2, axis=1, keepdims=True)
    
#     log_p_htilde = h_tilde_dist.log_prob(x[:, 2]).reshape((-1, 1))
    
#     res = logp + loglik + log_p_htilde
    
    return res

# %%
# check source of loss in quality by removing h and \tilde{g}
# note that this gives the same result for each sd, as h is
# not used

sd_list = [1] # [0.1, 1, 2, 5, 10]
nrep = 100

ess_list = -1 * np.ones((nrep, len(sd_list)))
energy_list = -1 * np.ones_like(ess_list)

# for constructing h_tilde
x3_mean = tf.math.reduce_mean(smc_res[:, 2])
x3_var = tf.math.reduce_variance(smc_res[:, 2])

for j, sd in enumerate(sd_list):
    print(f"Running for sd = {sd}")
    
    h_dist = Proposal(sd=np.ones(N)*sd)
#     h_tilde_dist = Proposal(N=N)
    h_tilde_dist = tfd.Laplace(
        loc=tf.ones(N) * x3_mean,
        scale=tf.ones(N) * x3_var
    )
    
    for i in range(nrep):
        ess, energy_dist = IS_augmented_experiment(
            h_dist=h_dist, 
            h_tilde_dist=h_tilde_dist, 
            log_target_old=log_target,
            log_target_new=log_target_new,
            log_target_aug_old=log_base_augment,
            log_target_aug_new=log_target_new_augment,
            init_samples=smc_res[:N, :], 
            true_samples=smc_res_new, 
            plot=False)
        ess_list[i, j] = ess
        energy_list[i, j] = energy_dist
# Out:
# Running for sd = 1

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)
_ = plt.xticks(range(1, 1 + len(sd_list)), sd_list)

plt.subplot(1, 2, 2)
_ = plt.plot(range(len(sd_list)), np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between(range(len(sd_list)),
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)
_ = plt.xticks(range(len(sd_list)), sd_list)

# %% [markdown]
# ### Change mean

# %%
mean_list = [-3, -2, -1, 0, 1, 2, 3]
nrep = 100

ess_list = -1 * np.ones((nrep, len(mean_list)))
energy_list = -1 * np.ones_like(ess_list)

# for constructing h_tilde
x3_mean = tf.math.reduce_mean(smc_res[:, 2])
x3_var = tf.math.reduce_variance(smc_res[:, 2])

for j, mean in enumerate(mean_list):
    print(f"Running for mean = {mean}")

#     h_dist = Proposal(mean=np.ones(N) * mean)
#     h_tilde_dist = Proposal(N=N)

#     h_dist = Proposal(mean=smc_res[:, 4] + mean)
    h_dist = Proposal(mean=tf.zeros_like(smc_res[:, 4]) + mean)
    h_tilde_dist = tfd.Laplace(
        loc=tf.ones(N) * x3_mean,
        scale=tf.ones(N) * x3_var * 100
    )
    
    for i in range(nrep):
        ess, energy_dist = IS_augmented_experiment(
            h_dist=h_dist, 
            h_tilde_dist=h_tilde_dist, 
            log_target_old=log_target,
            log_target_new=log_target_new,
            log_target_aug_old=log_base_augment,
            log_target_aug_new=log_target_new_augment,
            init_samples=smc_res[:N, :], 
            true_samples=smc_res_new, 
            plot=False)
        ess_list[i, j] = ess
        energy_list[i, j] = energy_dist
# Out:
# Running for mean = -3
# Running for mean = -2
# Running for mean = -1
# Running for mean = 0
# Running for mean = 1
# Running for mean = 2
# Running for mean = 3

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)
_ = plt.xticks(range(1, 1 + len(mean_list)), mean_list)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("$\mu_q$", fontsize=15)
plt.ylabel("Effective Sample Size", fontsize=15)

plt.subplot(1, 2, 2)
_ = plt.plot(range(len(mean_list)), np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between(range(len(mean_list)),
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)
_ = plt.xticks(range(len(mean_list)), mean_list)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel("$\mu_q$", fontsize=15)
plt.ylabel("Energy Distance", fontsize=15)
plt.tight_layout()
plt.savefig("figs/ais_mean.pdf")

# %% [markdown]
# ## Compare with D&C SMC

# %%
log_gamma1, log_gamma2, log_gamma3, log_gamma4, log_gamma5 = init_target(obs, mean_shift=2)

samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N, x_true.shape[1]))[:, :, 0]
dcsmc_init_samples = tf.Variable(samples_plot_init)
# dcsmc_init_samples = tf.identity(smc_res[:N, :])

# %%
class Proposal:
    def __init__(self, mean=0, sd=1):
        self.mean = np.zeros(1) + mean
        self.sd = np.ones(1) * sd

    def log_prob(self, mu_new, mu_curr=None):
        mu_curr = self.mean if mu_curr is None else mu_curr
        self.dist = tfd.Normal(mu_curr, self.sd)
        return self.dist.log_prob(mu_new) # nsample x dim

    def sample(self, size, mu_curr=None):
        mu_curr = self.mean if mu_curr is None else mu_curr
        self.dist = tfd.Normal(mu_curr, self.sd)
        return self.dist.sample(size)[:, :, 0]
    
class OldTarget:
    def __init__(self, log_prob):
        self.log_prob = log_prob
    def log_prob(self, x):
        return self.log_prob(x)
    
def log_gamma_1dim(x, obs):
    """density for x_i that only takes in x_i for i = 1, 2, 3"""
    loglik = tfd.Normal(loc=x, scale=sigma).log_prob(obs)
    loglik = tf.reduce_sum(loglik, axis=1, keepdims=True)
    logprior = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x)
    return loglik + logprior

def log_gamma4_proposal(x4):
    """density for x4 that only takes in x4"""
    x = dcsmc_init_samples
    print("x4", x4.shape)
    loglik1 = tfd.Normal(loc=x[:, 0:1], scale=sigma).log_prob(obs[:, :1].T)
    loglik2 = tfd.Normal(loc=x[:, 1:2], scale=sigma).log_prob(obs[:, 1:2].T)
    loglik = tf.reduce_sum(loglik1 + loglik2, axis=1, keepdims=True)
    logp1 = tfd.Normal(loc=x4, scale=tau).log_prob(x[:, 0:1])
    logp2 = tfd.Normal(loc=x4, scale=tau).log_prob(x[:, 1:2])
    logp4 = tfd.Normal(loc=mu0, scale=sigma0).log_prob(x4)
    return loglik + logp1 + logp2 + logp4

# %%
proposal = Proposal(sd=3)
proposal1 = OldTarget(lambda x: log_gamma_1dim(x, obs[:, :1]))
proposal2 = OldTarget(lambda x: log_gamma_1dim(x, obs[:, 1:2]))
proposal3 = OldTarget(lambda x: log_gamma_1dim(x, obs[:, 2:3]))
proposal4 = OldTarget(log_gamma4_proposal)

## reusing samples
# model = Model(log_gamma5, proposal, 4)
# model.build_child(log_gamma4, proposal4, 3, update=False)
# model.build_child(log_gamma3, proposal3, 2, update=False)
# model.children[0].build_child(log_gamma2, proposal2, 1, update=False)
# model.children[0].build_child(log_gamma1, proposal1, 0, update=False)

model = Model(log_gamma5, proposal, 4)
model.build_child(log_gamma4, proposal, 3)
model.build_child(log_gamma3, proposal, 2)
model.children[0].build_child(log_gamma2, proposal, 1)
model.children[0].build_child(log_gamma1, proposal, 0)

# %%
nrep = 100

ess_list, energy_list, dcsmc_samples = run_dcsmc_experiment(model, dcsmc_init_samples, smc_res_new, nrep)
# Out:
# Running repetition [0 / 100]
# Running repetition [10 / 100]
# Running repetition [20 / 100]
# Running repetition [30 / 100]
# Running repetition [40 / 100]
# Running repetition [50 / 100]
# Running repetition [60 / 100]
# Running repetition [70 / 100]
# Running repetition [80 / 100]
# Running repetition [90 / 100]

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)

plt.subplot(1, 2, 2)
_ = plt.plot([0], np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between([0],
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)

print("mean", ess_list.mean())
print("sd", ess_list.std())
print("95%-CI", np.percentile(ess_list, [2.5, 97.5]))
print("mean energy", energy_list.mean())
print("sd energy", energy_list.std())
# Out:
# mean 101.13898819483921
# sd 42.83797402796576
# 95%-CI [ 26.13763243 178.0886471 ]
# mean energy 0.0287101149559021
# sd energy 0.034220887295173454

# %%
# plot histograms
for i in range(5):
    plot_hist(i, smc_res_new, dcsmc_samples, label1="HMC new", label2="D&C SMC")
#     plot_hist(i, smc_res, dcsmc_samples, label1="HMC old", label2="D&C SMC")
#     plot_hist(i, dcsmc_init_samples, dcsmc_samples, label1="Initial", label2="D&C SMC")
# Out:
# true x_1: tf.Tensor(1.6739499345270943, shape=(), dtype=float64)
# estimate: tf.Tensor(1.2629944052158395, shape=(), dtype=float64)
# true x_2: tf.Tensor(-0.8109232714986124, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.24123580045972134, shape=(), dtype=float64)
# true x_3: tf.Tensor(0.4399671454377567, shape=(), dtype=float64)
# estimate: tf.Tensor(1.0304783976031795, shape=(), dtype=float64)
# true x_4: tf.Tensor(-0.5540992987520248, shape=(), dtype=float64)
# estimate: tf.Tensor(0.2490939145706206, shape=(), dtype=float64)
# true x_5: tf.Tensor(-1.0, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.2617529833942293, shape=(), dtype=float64)

# %% [markdown]
# ## Ordinary IS

# %%
def run_ordinary_IS_experiment(log_init_den, log_target_den, init_samples, true_samples, nrep):
    ess_list = -1 * np.ones(nrep)
    energy_list = -1 * np.ones_like(ess_list)
    
    for i in range(nrep):
        if i % 10 == 0:
            print(f"Running repetition [{i} / {nrep}]")
        # initialize samples and weights
        init_samples = tf.Variable(init_samples)

        log_w_init = np.ones_like(init_samples)
        log_w_init = tf.Variable(log_w_init)

        # compute log weights
        log_w = log_target_den(init_samples) - log_init_den(init_samples)

        # compute ESS
        ess = effective_sample_size(log_w)

        # resample from weighted empirical distribution
        samples_plot = resample(log_w, init_samples)

        # compute energy distance
        energy_dist = energy_distance(
            torch.Tensor(samples_plot.numpy()),
            torch.Tensor(true_samples.numpy())
        )
        
        ess_list[i] = ess
        energy_list[i] = energy_dist

    return ess_list, energy_list, samples_plot

# %%
ess_list, energy_list, ord_is_samples = run_ordinary_IS_experiment(
    log_init_den=log_target, 
    log_target_den=log_target_new, 
    init_samples=smc_res[:N, :], 
    true_samples=smc_res_new, 
    nrep=nrep)
# Out:
# Running repetition [0 / 100]
# Running repetition [10 / 100]
# Running repetition [20 / 100]
# Running repetition [30 / 100]
# Running repetition [40 / 100]
# Running repetition [50 / 100]
# Running repetition [60 / 100]
# Running repetition [70 / 100]
# Running repetition [80 / 100]
# Running repetition [90 / 100]

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)

plt.subplot(1, 2, 2)
_ = plt.plot([0], np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between([0],
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)

print("mean", ess_list.mean())
print("sd", ess_list.std())
print("95%-CI", np.percentile(ess_list, [2.5, 97.5]))
print("mean energy", energy_list.mean())
print("sd energy", energy_list.std())
# Out:
# mean 231.32931608058908
# sd 2.842170943040401e-14
# 95%-CI [231.32931608 231.32931608]
# mean energy 0.004306626319885254
# sd energy 0.0006227107738029028

# %%
# plot histograms
for i in range(5):
    plot_hist(i, smc_res_new, ord_is_samples, label1="HMC new", label2="Ordinary IS")
# Out:
# true x_1: tf.Tensor(1.6739499345270943, shape=(), dtype=float64)
# estimate: tf.Tensor(1.2629944052158395, shape=(), dtype=float64)
# true x_2: tf.Tensor(-0.8109232714986124, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.24123580045972134, shape=(), dtype=float64)
# true x_3: tf.Tensor(0.4399671454377567, shape=(), dtype=float64)
# estimate: tf.Tensor(1.0304783976031795, shape=(), dtype=float64)
# true x_4: tf.Tensor(-0.5540992987520248, shape=(), dtype=float64)
# estimate: tf.Tensor(0.2490939145706206, shape=(), dtype=float64)
# true x_5: tf.Tensor(-1.0, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.2617529833942293, shape=(), dtype=float64)

# %% [markdown]
# ## 2. x = {x_1, x_2}, y = {x_3, x_4}, z = {x_5}
# $p(x_5) = \mathcal{N}(0, 1) \to p(x_5) = \mathcal{N}(- 2, 1)$

# %%
def logprior_new(x):
    logp1 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 0:1])
    logp2 = tfd.Normal(loc=x[:, 3:4], scale=tau).log_prob(x[:, 1:2])   
    logp3 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 2:3])
    logp4 = tfd.Normal(loc=x[:, 4:5], scale=gamma).log_prob(x[:, 3:4])
    logprior5 = tfd.Normal(loc=mu0 - 2, scale=sigma0).log_prob(x[:, 4:5])
    return logp1 + logp2 + logp3 + logp4 + logprior5

def log_target_new(x):
    return logprior_new(x) + loglik(x)

# %%
N = 2000

# given samples from old target
samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N, x_true.shape[1]))[:, :, 0]
samples_init = tf.Variable(samples_plot_init)

# %%
smc_res = tfp.experimental.mcmc.sample_sequential_monte_carlo(
    prior_log_prob_fn=logprior,
    likelihood_log_prob_fn=loglik,
    current_state=samples_init,
    seed=(12, 34))[1]

# %%
# get samples from new target (unavailable in practice)
samples_plot_init = tfd.Normal(loc=np.zeros(1), scale=np.ones(1)).sample((N, x_true.shape[1]))[:, :, 0]
samples_init = tf.Variable(samples_plot_init)

# %%
smc_res_new = tfp.experimental.mcmc.sample_sequential_monte_carlo(
    prior_log_prob_fn=logprior_new,
    likelihood_log_prob_fn=loglik,
    current_state=samples_init,
    seed=(12, 34))[1]

# %%
# visualize old and new targets
for i in range(5):
    plot_hist(i, smc_res_new, smc_res, label1="HMC new", label2="HMC old")
# Out:
# true x_1: tf.Tensor(1.6739499345270943, shape=(), dtype=float64)
# estimate: tf.Tensor(1.2017307522341083, shape=(), dtype=float64)
# true x_2: tf.Tensor(-0.8109232714986124, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.27213389391993814, shape=(), dtype=float64)
# true x_3: tf.Tensor(0.4399671454377567, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.09325495014021735, shape=(), dtype=float64)
# true x_4: tf.Tensor(-0.5540992987520248, shape=(), dtype=float64)
# estimate: tf.Tensor(0.10066928217382669, shape=(), dtype=float64)
# true x_5: tf.Tensor(-1.0, shape=(), dtype=float64)
# estimate: tf.Tensor(-0.6392413489493208, shape=(), dtype=float64)

# %% [markdown]
# ## Importance sampling

# %% [markdown]
# ### change sd

# %%
sd_list = [0.1, 1, 2, 5, 10]
nrep = 100

ess_list = -1 * np.ones((nrep, len(sd_list)))
energy_list = -1 * np.ones_like(ess_list)

# for constructing h_tilde
x3_mean = tf.math.reduce_mean(smc_res[:, 2])
x3_var = tf.math.reduce_variance(smc_res[:, 2])

for j, sd in enumerate(sd_list):
    print(f"Running for sd = {sd}")
    
    h_dist = Proposal(sd=np.ones(N)*sd)
#     h_tilde_dist = Proposal(N=N)
    h_tilde_dist = tfd.Laplace(
        loc=tf.ones(N) * x3_mean,
        scale=tf.ones(N) * x3_var
    )
    
    for i in range(nrep):
        ess, energy_dist = IS_augmented_experiment(
            h_dist=h_dist, 
            h_tilde_dist=h_tilde_dist, 
            log_target_old=log_target,
            log_target_new=log_target_new,
            log_target_aug_old=log_base_augment,
            log_target_aug_new=log_target_new_augment,
            init_samples=smc_res[:N, :], 
            true_samples=smc_res_new, 
            plot=False)
        ess_list[i, j] = ess
        energy_list[i, j] = energy_dist
# Out:
# Running for sd = 0.1
# Running for sd = 1
# Running for sd = 2
# Running for sd = 5
# Running for sd = 10

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)
_ = plt.xticks(range(1, 1 + len(sd_list)), sd_list)

plt.subplot(1, 2, 2)
_ = plt.plot(range(len(sd_list)), np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between(range(len(sd_list)),
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)
_ = plt.xticks(range(len(sd_list)), sd_list)

# %% [markdown]
# ### change mean

# %%
mean_list = [-2, -1, 0, 1, 2]
nrep = 100

ess_list = -1 * np.ones((nrep, len(sd_list)))
energy_list = -1 * np.ones_like(ess_list)

# for constructing h_tilde
x3_mean = tf.math.reduce_mean(smc_res[:, 2])
x3_var = tf.math.reduce_variance(smc_res[:, 2])

for j, mean in enumerate(mean_list):
    print(f"Running for mean = {mean}")

#     h_dist = Proposal(mean=np.ones(1) * mean)
#     h_tilde_dist = Proposal()
    
    h_dist = Proposal(mean=np.ones(N) * (mu0 + mean))
    h_tilde_dist = tfd.Laplace(
        loc=tf.ones(N) * x3_mean,
        scale=tf.ones(N) * x3_var
    )
    
    for i in range(nrep):
        ess, energy_dist = IS_augmented_experiment(
            h_dist=h_dist, 
            h_tilde_dist=h_tilde_dist, 
            log_target_old=log_target,
            log_target_new=log_target_new,
            log_target_aug_old=log_base_augment,
            log_target_aug_new=log_target_new_augment,
            init_samples=smc_res[:N, :], 
            true_samples=smc_res_new, 
            plot=False)
        ess_list[i, j] = ess
        energy_list[i, j] = energy_dist
# Out:
# Running for mean = -2
# Running for mean = -1
# Running for mean = 0
# Running for mean = 1
# Running for mean = 2

# %%
plt.subplot(1, 2, 1)
_ = plt.boxplot(ess_list)
_ = plt.xticks(range(1, 1 + len(mean_list)), mean_list)

plt.subplot(1, 2, 2)
_ = plt.plot(range(len(mean_list)), np.mean(energy_list, axis=0), marker="o")
_ = plt.fill_between(range(len(mean_list)),
                     np.percentile(energy_list, 2.5, axis=0), 
                     np.percentile(energy_list, 97.5, axis=0),
                     color='b', alpha=.1)
_ = plt.xticks(range(len(mean_list)), mean_list)
